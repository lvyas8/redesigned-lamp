# %%
import cufflinks
import plotly.plotly as py
import plotly.graph_objs as go

# %%
from plotly.offline import iplot, init_notebook_mode
cufflinks.go_offline(connected=True)
init_notebook_mode(connected=True)
import pandas_datareader as pdr
import pandas as pd # importing necessary packages to pull, clean and plot data
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pdr.get_data_yahoo(['AAPL','MSFT','FB'], start = '2015-1-1',end='2019-7-31') # pulling data from yahoo API

# %%
df=df['Close'] # removing columns we dont need

# %%
spy = pdr.get_data_yahoo('SPY', start='2015-1-1',end='2019-7-31') # pulling S&P data from yahoo API

# %%
spy=spy['Close'] # removing columns we dont need

# %%
comb_data = pd.concat([df,spy],axis=1) # combining both dataframes to calculate co-relation co-efficient

# %%
comb_data.columns = ['Apple','Facebook','Microsoft','S&P'] # To have clear column headings

# %%
comb_data.head() # a glimpse of the data to make sure thinhs are right
# Out:
#                  Apple   Facebook  Microsoft         S&P
# Date
# 2015-01-02  109.330002  78.449997  46.759998  205.429993
# 2015-01-05  106.250000  77.190002  46.330002  201.720001
# 2015-01-06  106.260002  76.150002  45.650002  199.820007
# 2015-01-07  107.750000  76.150002  46.230000  202.309998
# 2015-01-08  111.889999  78.180000  47.590000  205.899994

# %%
corr_mat = comb_data.corr() # calulating co-relation 
corr_mat # display result
# Out:
#               Apple  Facebook  Microsoft       S&P
# Apple      1.000000  0.802670   0.900385  0.950222
# Facebook   0.802670  1.000000   0.848007  0.901601
# Microsoft  0.900385  0.848007   1.000000  0.954813
# S&P        0.950222  0.901601   0.954813  1.000000

# %%
import plotly.figure_factory as ff # package required to make an interactive co-relation matrix

# %%
figure = ff.create_annotated_heatmap(z=corr_mat.values,x=list(corr_mat.columns),y=list(corr_mat.index),annotation_text=corr_mat.round(2).values,showscale=True)

# %%
figure.show()
# Out:
# <div>
#
#
#             <div id="7c8a6c0b-9a1f-4cdc-b008-b943b3df3513" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("7c8a6c0b-9a1f-4cdc-b008-b943b3df3513")) {
#                     Plotly.newPlot(
#                         '7c8a6c0b-9a1f-4cdc-b008-b943b3df3513',
#                         [{"colorscale": "RdBu", "reversescale": false, "showscale": true, "type": "heatmap", "uid": "2755d024-a587-4b4a-aab1-a0ebf8b74030", "x": ["Apple", "Facebook", "Microsoft", "S&P"], "y": ["Apple", "Facebook", "Microsoft", "S&P"], "z": [[1.0, 0.8026695215865429, 0.9003845302566019, 0.9502221777778096], [0.8026695215865429, 1.0, 0.8480069976296879, 0.9016005837620287], [0.9003845302566019, 0.8480069976296879, 1.0, 0.9548128080492527], [0.9502221777778096, 0.9016005837620287, 0.9548128080492527, 1.0]]}],
#                         {"annotations": [{"font": {"color": "#000000"}, "showarrow": false, "text": "1.0", "x": "Apple", "xref": "x", "y": "Apple", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "0.8", "x": "Facebook", "xref": "x", "y": "Apple", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "0.9", "x": "Microsoft", "xref": "x", "y": "Apple", "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "0.95", "x": "S&P", "xref": "x", "y": "Apple", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "0.8", "x": "Apple", "xref": "x", "y": "Facebook", "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "1.0", "x": "Facebook", "xref": "x", "y": "Facebook", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "0.85", "x": "Microsoft", "xref": "x", "y": "Facebook", "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "0.9", "x": "S&P", "xref": "x", "y": "Facebook", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "0.9", "x": "Apple", "xref": "x", "y": "Microsoft", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "0.85", "x": "Facebook", "xref": "x", "y": "Microsoft", "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "1.0", "x": "Microsoft", "xref": "x", "y": "Microsoft", "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "0.95", "x": "S&P", "xref": "x", "y": "Microsoft", "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "0.95", "x": "Apple", "xref": "x", "y": "S&P", "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "0.9", "x": "Facebook", "xref": "x", "y": "S&P", "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "0.95", "x": "Microsoft", "xref": "x", "y": "S&P", "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "1.0", "x":
213992432463, -0.01104283544121143, -0.0019658724825007967, 0.005357708123117311, -0.0023510613319022156, 0.004556120877894587, -0.01000937446659711, 0.007977900066380661, -0.004545112673619345, 0.008501943174313409, -0.004761537799120696, -0.00588235294117645, -0.01751480253020221, 0.007227186498844906, 0.009327897361864457, -0.0012637917428375278, -0.0034799306620557635, -0.002460298084077328, -0.024822998535913854, -0.02039650816859362, 0.02673439737345995, 0.019305685483282042, -0.00039792336702670905, 0.009632983668443229, 0.013325932944949326, 0.008637465238491737, 0.018901498991851007, -0.009994754683235962, -0.04229444573076002, -0.00047913718262948546, -0.005273279344823023, -0.013895609292639333, 0.00496864565472821, -0.0031609612443692647, -0.005041020635468629, -0.008743970505909804, -0.023577910456698215, -0.03208378059294381, 0.006629467378548304, -0.0023397250337158226, 0.003387469807629717, 0.0363573814030993, -0.052038116383315236, 0.015419861070934626, -0.0007809470631630067, 0.007034281787757557, 0.010348435556321034, -0.005633353034136368, -0.012789681234073202, -0.020519959712339775, -0.061162887672625676, -0.024962172242090408, 0.006012365212122228, 0.05735497108309384, 0.02944658269348155, 0.0032766804160628826, -0.004678248521615469, -0.044696708230266724, 0.042888925592581284, -0.017535994797287957, -0.009966531450047333, 0.02782100310168034, -0.019232446618013155 ...

# %%
appl = comb_data['Apple'] # segregating appl data from the combined data for a deep dive in the time series data
sma1 = appl.rolling(30).mean() # calculates 30 day moving average 
sma2 = appl.rolling(50).mean() # calculates 50 day moving average

# %%
appl_full = pd.concat([appl,sma1,sma2],axis=1) #combining closing prices with moving average calculations
appl_full.columns = ['Closing','sma30','sma50'] #renaming columns to avoid confusion

# %%
appl_full.iplot(kind='line',xTitle = 'Timeframe', yTitle='Price',title='Apple stock price and 30, 50 day Mvg Avg')
# an interactive plot of stock prices and moving averages to develop a crossover trading strategy or to take trading positions at
# certain levels
# Out:
# <div>
#
#
#             <div id="60b233d0-915b-4553-966f-c98ba56b5d68" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("60b233d0-915b-4553-966f-c98ba56b5d68")) {
#                     Plotly.newPlot(
#                         '60b233d0-915b-4553-966f-c98ba56b5d68',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Closing", "text": "", "type": "scatter", "uid": "92331ec4-6706-429e-8d90-f9907d97f4af", "x": ["2015-01-02", "2015-01-05", "2015-01-06", "2015-01-07", "2015-01-08", "2015-01-09", "2015-01-12", "2015-01-13", "2015-01-14", "2015-01-15", "2015-01-16", "2015-01-20", "2015-01-21", "2015-01-22", "2015-01-23", "2015-01-26", "2015-01-27", "2015-01-28", "2015-01-29", "2015-01-30", "2015-02-02", "2015-02-03", "2015-02-04", "2015-02-05", "2015-02-06", "2015-02-09", "2015-02-10", "2015-02-11", "2015-02-12", "2015-02-13", "2015-02-17", "2015-02-18", "2015-02-19", "2015-02-20", "2015-02-23", "2015-02-24", "2015-02-25", "2015-02-26", "2015-02-27", "2015-03-02", "2015-03-03", "2015-03-04", "2015-03-05", "2015-03-06", "2015-03-09", "2015-03-10", "2015-03-11", "2015-03-12", "2015-03-13", "2015-03-16", "2015-03-17", "2015-03-18", "2015-03-19", "2015-03-20", "2015-03-23", "2015-03-24", "2015-03-25", "2015-03-26", "2015-03-27", "2015-03-30", "2015-03-31", "2015-04-01", "2015-04-02", "2015-04-06", "2015-04-07", "2015-04-08", "2015-04-09", "2015-04-10", "2015-04-13", "2015-04-14", "2015-04-15", "2015-04-16", "2015-04-17", "2015-04-20", "2015-04-21", "2015-04-22", "2015-04-23", "2015-04-24", "2015-04-27", "2015-04-28", "2015-04-29", "2015-04-30", "2015-05-01", "2015-05-04", "2015-05-05", "2015-05-06", "2015-05-07", "2015-05-08", "2015-05-11", "2015-05-12", "2015-05-13", "2015-05-14", "2015-05-15", "2015-05-18", "2015-05-19", "2015-05-20", "2015-05-21", "2015-05-22", "2015-05-26", "2015-05-27", "2015-05-28", "2015-05-29", "2015-06-01", "2015-06-02", "2015-06-03", "2015-06-04", "2015-06-05", "2015-06-08", "2015-06-09", "2015-06-10", "2015-06-11", "2015-06-12", "2015-06-15", "2015-06-16", "2015-06-17", "2015-06-18", "2015-06-19", "2015-06-22", "2015-06-23", "2015-06-24", "2015-06-25", "2015-06-26", "2015-06-29", "2015-06-30", "2015-07-01", "2015-07-02", "2015-07-06", "2015-07-07", "2015-07-08", "2015-07-09", "2015-07-10", "2015-07-13", "2015-07-14", "2015-07-15", "2015-07-16", "2015-07-17", "2015-07-20", "2015-07-21", "2015-07-22", "2015-07-23", "2015-07-24", "2015-07-27", "2015-07-28", "2015-07-29", "2015-07-30", "2015-07-31", "2015-08-03", "2015-08-04", "2015-08-05", "2015-08-06", "2015-08-07", "2015-08-10", "2015-08-11", "2015-08-12", "2015-08-13", "2015-08-14", "2015-08-17", "2015-08-18", "2015-08-19", "2015-08-20", "2015-08-21", "2015-08-24", "2015-08-25", "2015-08-26", "2015-08-27", "2015-08-28", "2015-08-31", "2015-09-01", "2015-09-02", "2015-09-03", "2015-09-04", "2015-09-08", "2015-09-09", "2015-09-10", "2015-09-11", "2015-09-14", "2015-09-15", "2015-09-16", "2015-09-17", "2015-09-18", "2015-09-21", "2015-09-22", "2015-09-23", "2015-09-24", "2015-09-25", "2015-09-28", "2015-09-29", "2015-09-30", "2015-10-01", "2015-10-02", "2015-10-05", "2015-10-06", "2015-10-07", "2015-10-08", "2015-10-09", "2015-10-12", "2015-10-13", "2015-10-14", "2015-10-15", "2015-10-16", "2015-10-19", "2015-10-20", "2015-10-21", "2015-10-22", "2015-10-23", "2015-10-26", "2015-10-27", "2015-10-28", "2015-10-29", "2015-10-30", "2015-11-02", "2015-11-03", "2015-11-04", "2015-11-05", "2015-11-06", "2015-11-09", "2015-11-10", "2015-11-11", "2015-11-12", "2015-11-13", "2015-11-16", "2015-11-17", "2015-11-18", "2015-11-19", "2015-11-20", "2015-11-23", "2015-11-24", "2015-11-25", "2015-11-27", "2015-11-30", "2015-12-01", "2015-12-02", "2015-12-03", "2015-12-04", "2015-12-07", "2015-12-08", "2015-12-09", "2015-12-10", "2015-12-11", "2015-12-14", "2015-12-15", "2015-12-16", "2015-12-17", "2015-12-18", "2015-12-21", "2015-12-22", "2015-12-23", "2015-12-24", "2015-12-28", "2015-12-29", "2015-12-30", "2015-12-31", "2016-01-04", "2016-01-05", "2016-01-06", "2016-01-07", "2016-01-08", "2016-01-11", "2016-01-12", "2016-01-13", "2016-01-14", "2016-01-15", "2016-01-19", "2016-01-20", "2016-01-21", "2016-01-22", "2016-01-25", "2016-01-26", "2016- ...

# %%
appl_returns = appl.pct_change() # calculates returns useful for an interactve histogram plot
appl_returns.iplot(kind='hist',xTitle = 'Timeframe',yTitle = 'Percentage Returns', title = 'Distribution of Apple returns')
# Out:
# <div>
#
#
#             <div id="7305b2dd-ceb4-4456-b0e5-72e0657ca3ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("7305b2dd-ceb4-4456-b0e5-72e0657ca3ec")) {
#                     Plotly.newPlot(
#                         '7305b2dd-ceb4-4456-b0e5-72e0657ca3ec',
#                         [{"histfunc": "count", "histnorm": "", "marker": {"color": "rgba(255, 153, 51, 1.0)", "line": {"color": "#4D5663", "width": 1.3}}, "name": "Apple", "opacity": 0.8, "orientation": "v", "type": "histogram", "uid": "2b627d5a-50d1-43a8-bcf2-281c2ce47849", "x": [null, -0.028171606873419353, 9.413775275746161e-05, 0.014022189288677822, 0.038422268117386915, 0.0010725064548811059, -0.02464067568603079, 0.008878729708952982, -0.0038105440418596537, -0.02714028482794184, -0.0077700976729632165, 0.02575717909196018, 0.007634306675271096, 0.02601550337497094, 0.005160158569225137, 0.001062091641194307, -0.035013254976999475, 0.056532877070278875, 0.03113350137277493, -0.014634128187044793, 0.0125468892570888, 0.00016862743761336674, 0.007669582983666157, 0.003178361413283426, -0.008420894744636032, 0.0066425705330883655, 0.01921145505272137, 0.023438786174676318, 0.012652161000999973, 0.004902757797490498, 